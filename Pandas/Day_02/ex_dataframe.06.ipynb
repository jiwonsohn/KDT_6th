# %% [markdown]
# #### DataFrame에서 행/열 추가
# -    행방향 추가
# -    열방향 추가

# %%
# 모듈 로딩
import pandas as pd

# %%
# 데이터 준비
data = {'name': ['홍길동','마징가','원더우먼'], 
        'job':['의적','로봇', '영웅'],
        'gender': ['남','남','여'],
        'age': [100,200,300],
        'height': [180,300,200] }

# %%
# DF로 데이터 저장
dataDF = pd.DataFrame(data)
dataDF
# Out:
#    name job gender  age  height
# 0   홍길동  의적      남  100     180
# 1   마징가  로봇      남  200     300
# 2  원더우먼  영웅      여  300     200

# %% [markdown]
# #### [실습]
#   * 행 추가: DF_변수명.loc[ '추가할 행 이름'] = 열 개수와 같은 길이의 데이터 리스트/튜플              / iloc는 불가!!
#   *      1개 행 추가 w/ 데이터 수 1개   --> 모든 컬럼에 동일 값 저장
#   * 열 추가: DF_변수명.[ '추가할 열 이름'] = 행 개수와 같은 길이의 데이터 리스트/튜플
#   *      1개 열 추가 w/ 데이터 수 1개   --> 모든 행에 동일 값 저장

# %%
# 1개 행 추가 w/ 열 개수와 똑같은

dataDF.loc[3] = ['배트맨','박쥐','남', 40,190]
dataDF
# Out:
#    name job gender  age  height
# 0   홍길동  의적      남  100     180
# 1   마징가  로봇      남  200     300
# 2  원더우먼  영웅      여  300     200
# 3   배트맨  박쥐      남   40     190

# %%
# 1개 행 추가 w/ 데이터 수 1개   --> 모든 컬럼에 동일 값 저장

dataDF.loc[4] = 100
dataDF
# Out:
#    name  job gender  age  height
# 0   홍길동   의적      남  100     180
# 1   마징가   로봇      남  200     300
# 2  원더우먼   영웅      여  300     200
# 3   배트맨   박쥐      남   40     190
# 4   100  100    100  100     100

# %%
# 1개 행 추가 w/ 데이터 수 2개         --> ERROR

# dataDF.loc[5] = ['스파이더맨', '거미']
# dataDF

# %%
## gender, height 컬럼 삭제

dataDF.drop( ["gender","height"], axis=1)

# %%
## [실습] weight 열 추가
dataDF['weight'] = [60,3000,68,88,0]
dataDF
# Out:
#    name  job gender  age  height  weight
# 0   홍길동   의적      남  100     180      60
# 1   마징가   로봇      남  200     300    3000
# 2  원더우먼   영웅      여  300     200      68
# 3   배트맨   박쥐      남   40     190      88
# 4   100  100    100  100     100       0

# %%
## [실습] weight 열 추가
dataDF['weight_2'] = 0
dataDF
# Out:
#    name  job gender  age  height  weight  weight_2
# 0   홍길동   의적      남  100     180      60         0
# 1   마징가   로봇      남  200     300    3000         0
# 2  원더우먼   영웅      여  300     200      68         0
# 3   배트맨   박쥐      남   40     190      88         0
# 4   100  100    100  100     100       0         0

# %%
## [실습] weight_3 열 추가
dataDF['weight_3'] = [0,90]         # ERROR
dataDF

# %%
dataDF['weight_4'] = 72
dataDF
# Out:
#    name  job gender  age  height  weight  weight_2  weight_4
# 0   홍길동   의적      남  100     180      60         0        72
# 1   마징가   로봇      남  200     300    3000         0        72
# 2  원더우먼   영웅      여  300     200      68         0        72
# 3   배트맨   박쥐      남   40     190      88         0        72
# 4   100  100    100  100     100       0         0        72
